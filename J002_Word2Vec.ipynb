# %% [markdown]
# <a href="https://colab.research.google.com/github/maaz-ansari/NLP/blob/master/J002_Word2Vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install gensim

# %%
import pandas as pd
from gensim.models import Word2Vec
from gensim.parsing.preprocessing import strip_punctuation,remove_stopwords
from itertools import permutations
from gensim import models

# %%
df=pd.read_json("http://snap.stanford.edu/data/amazon/productGraph/categoryFiles/reviews_Office_Products_5.json.gz",lines= True,orient='values')

# %%
df.head()
# Out:
#        reviewerID        asin  ... unixReviewTime   reviewTime
# 0  A32T2H8150OJLU  B00000JBLH  ...     1094169600   09 3, 2004
# 1  A3MAFS04ZABRGO  B00000JBLH  ...     1197676800  12 15, 2007
# 2  A1F1A0QQP2XVH5  B00000JBLH  ...     1293840000   01 1, 2011
# 3   A49R5DBXXQDE5  B00000JBLH  ...     1145404800  04 19, 2006
# 4  A2XRMQA6PJ5ZJ8  B00000JBLH  ...     1375574400   08 4, 2013
#
# [5 rows x 9 columns]

# %%
df = df[0:50]

# %%
df['p_rt'] = df['reviewText'].apply(strip_punctuation)

# %%
df['s_rT'] = df['p_rt'].apply(remove_stopwords)

# %%
df.head()
# Out:
#        reviewerID  ...                                               s_rT
# 0  A32T2H8150OJLU  ...  I bought HP12C 1984 served faithfully 2002 I l...
# 1  A3MAFS04ZABRGO  ...  WHY THIS BELATED REVIEW I feel obliged share v...
# 2  A1F1A0QQP2XVH5  ...  I HP 48GX kicking years HP 11 25 years old fla...
# 3   A49R5DBXXQDE5  ...  I ve started finance stuff recently went looki...
# 4  A2XRMQA6PJ5ZJ8  ...  For simple calculations discounted cash flows ...
#
# [5 rows x 11 columns]

# %%
unique = set()
df['p_rt'].str.lower().str.split().apply(unique.update)
unique = list(unique)
print(len(unique))
print(unique)
# Out:
# 1579
# ['such', 'about', 'loads', 'kicking', 'beautiful', 'snap', 'wish', 'frank', 'totally', '32sii', 'ended', 'flagship', 'requires', 'consider', 'meerkats', 'mention', 'pink', 'excel', 'method', 'displaying', 'saver', 'sized', 'eight', 'never', 'floor', 'use', 'listen', 'them', 'hate', 'memory', 'won', 'equations', 'scroll', 'gres', 'intelligent', '34', 'plastic', 'inputs', 'ships', 'complexity', 'angles', 'treated', 'he', 'durability', 'creatures', 'management', 'with', 'depend', 'sells', 'brandname', 'via', 'slows', 'career', 'range', 'computations', 'platiunum', 'fairly', 'downside', 'differ', 'commercially', 'values', 'semester', 'greater', 'magnum', 'from', 'files', 'punching', 'myself', 'sense', 'answer', 'we', 'experience', 'catalogue', 'courses', 'simple', 'buck', 'understand', 'interface', 'time', 'takes', 'how', 'after', 'print', 'needed', 'line', 'sketchy', '99', 'stuff', 'proposition', 'pricey', 'gives', 'rim', 'puzzling', 'telecommunications', 'shops', 'lcd', 'retro', 'homework', 'desktop', 'picked', 'travel', 'go', 'flows', 'forwards', 'comparable', 'alot', 'case', 'ibm', 'parenthesis', 'pre', 'hp12cplatinum', 'exhibits', 'etc', 'even', 'been', 'wife', 'lamp', 'capability', 'memorize', 'side', 'three', 'already', 'overview', 'kind', 'end', 'little', 'course', '50', 'appears', 'says', 'on', '2031', 'next', 'too', 'work', 'instructions', '9mm', 'trace', 'replace', 'activities', 'par', 'this', 'networking', 'light', 'whistles', 'safari', 'undergraduate', 'tell', 'clumsy', 'a', 'make', 'aside', 'press', 'upgrades', 'display', 'push', 'could', 'corporate', 'methods', 'between', 'deviation', 'hps', 'job', 'financial', 'good', 'backwards', 'integration', 'out', 'manufacturing', 'professionals', 'successfully', 'know', 'designated', 'necessary', 'originally', 'rate', '25th', 'programs', 'proven', 'middle', 'isn', 'successors', 'class', 'probably', 'iii', 'geometry', '5v', 'quality', 'cashier', 'ohio', 'bookstore', 'solving', 'bonus', 'sofware', 'views', 'any', 'home', 'going', 'shop', 'confirms', 'free', 'well', 'mark', 'pros', 'above', 'opened', 'me', 'their', 'business', 'why', 'to', 'products', 'now', 'power', 'typical', 'here', 'cases', 'frankly', 'several', 'trouble', 'seemed', 'own', '15', 'twenty', 'layout', 'white', 'calculators', 'graduate', 'relevant', 'complaining', 'frills', '1oth', 'students', 'dearly', 'calculation', 'form', 'number', 'tvm', 'ti', 'pixel', 'tests', 'cover', 'best', 'bone', 'qwerty', 'learn', 'sat', 'square', 'offered', 'face', 'completely', 'handheld', 'key', 'disturbing', 'his', 'slow', 'scratched', 'detailed', 'team', 'means', 'later', 'variables', 'diff', 'arithmetical', 'storing', 'name', 'vary', 'what', 'ever', 'priced', 'see', '3rd', 'mrc', 'bugs', 'gets', 'fault', 'prime', 'colors', 'deal', 'burying', 'tackle', 'if', 'analysis', 'relatively', 'old', 'received', 'having', 'ba', 'care', 'think', 'soent', 'mound', 'theorems', 'praising', 'enclosed', 'synonymous', 'ask', 'keller', 'rights', 'different', 'through', 'heard', 'obsolence', '8x', 'reliable', 'register', 'opportunity', 'lucrative', 'didn', 'competitors', 'version', 'level', 'should', 'traditional', 'potential', 'windshield', 'obviate', 'professional', 'delicate', 'being', 'have', 'wonderful', 'data', 'users', 'difficult', 'bear', 'programmable', 'companion', 'cheaper', 'physics', 'bargain', 'replaceable', 'numberical', 'compared', '2002', 'led', 'son', 'cheap', 'bottom', 'as', 'years', 'doesn', 'please', 'dowload', 'run', 'specifications', 'still', 'including', 'something', 'calculations', 'caught', 'construction', 'owned', 'purpose', 'fun', 'sculpted', 'senior', 'only', 'disaster', 'piece', 'cable', 'backpack', '00', 'defect', 'treat', 'lukasiewicz', 'doing', 'advantage', 'fact', 'narrow', 'dead', 'ap', 'regular', 'bought', 'instruction', 'disappeared', 'working', 'worthwhile', 'tire', 'desl', 'freeze', 'listed', 'over', 'calls', 'realized', 'meets', 'wal', 'college', 'devices', 'complex', 'fast', 'usually', 'program', 'desktops' ...

# %%
f = unique[0:20]

# %%
f
# Out:
# ['such',
#  'about',
#  'loads',
#  'kicking',
#  'beautiful',
#  'snap',
#  'wish',
#  'frank',
#  'totally',
#  '32sii',
#  'ended',
#  'flagship',
#  'requires',
#  'consider',
#  'meerkats',
#  'mention',
#  'pink',
#  'excel',
#  'method',
#  'displaying']

# %%
tr = []
tr = list(permutations(f, 2))
print(len(tr))
print(tr)
# Out:
# 380
# [('such', 'about'), ('such', 'loads'), ('such', 'kicking'), ('such', 'beautiful'), ('such', 'snap'), ('such', 'wish'), ('such', 'frank'), ('such', 'totally'), ('such', '32sii'), ('such', 'ended'), ('such', 'flagship'), ('such', 'requires'), ('such', 'consider'), ('such', 'meerkats'), ('such', 'mention'), ('such', 'pink'), ('such', 'excel'), ('such', 'method'), ('such', 'displaying'), ('about', 'such'), ('about', 'loads'), ('about', 'kicking'), ('about', 'beautiful'), ('about', 'snap'), ('about', 'wish'), ('about', 'frank'), ('about', 'totally'), ('about', '32sii'), ('about', 'ended'), ('about', 'flagship'), ('about', 'requires'), ('about', 'consider'), ('about', 'meerkats'), ('about', 'mention'), ('about', 'pink'), ('about', 'excel'), ('about', 'method'), ('about', 'displaying'), ('loads', 'such'), ('loads', 'about'), ('loads', 'kicking'), ('loads', 'beautiful'), ('loads', 'snap'), ('loads', 'wish'), ('loads', 'frank'), ('loads', 'totally'), ('loads', '32sii'), ('loads', 'ended'), ('loads', 'flagship'), ('loads', 'requires'), ('loads', 'consider'), ('loads', 'meerkats'), ('loads', 'mention'), ('loads', 'pink'), ('loads', 'excel'), ('loads', 'method'), ('loads', 'displaying'), ('kicking', 'such'), ('kicking', 'about'), ('kicking', 'loads'), ('kicking', 'beautiful'), ('kicking', 'snap'), ('kicking', 'wish'), ('kicking', 'frank'), ('kicking', 'totally'), ('kicking', '32sii'), ('kicking', 'ended'), ('kicking', 'flagship'), ('kicking', 'requires'), ('kicking', 'consider'), ('kicking', 'meerkats'), ('kicking', 'mention'), ('kicking', 'pink'), ('kicking', 'excel'), ('kicking', 'method'), ('kicking', 'displaying'), ('beautiful', 'such'), ('beautiful', 'about'), ('beautiful', 'loads'), ('beautiful', 'kicking'), ('beautiful', 'snap'), ('beautiful', 'wish'), ('beautiful', 'frank'), ('beautiful', 'totally'), ('beautiful', '32sii'), ('beautiful', 'ended'), ('beautiful', 'flagship'), ('beautiful', 'requires'), ('beautiful', 'consider'), ('beautiful', 'meerkats'), ('beautiful', 'mention'), ('beautiful', 'pink'), ('beautiful', 'excel'), ('beautiful', 'method'), ('beautiful', 'displaying'), ('snap', 'such'), ('snap', 'about'), ('snap', 'loads'), ('snap', 'kicking'), ('snap', 'beautiful'), ('snap', 'wish'), ('snap', 'frank'), ('snap', 'totally'), ('snap', '32sii'), ('snap', 'ended'), ('snap', 'flagship'), ('snap', 'requires'), ('snap', 'consider'), ('snap', 'meerkats'), ('snap', 'mention'), ('snap', 'pink'), ('snap', 'excel'), ('snap', 'method'), ('snap', 'displaying'), ('wish', 'such'), ('wish', 'about'), ('wish', 'loads'), ('wish', 'kicking'), ('wish', 'beautiful'), ('wish', 'snap'), ('wish', 'frank'), ('wish', 'totally'), ('wish', '32sii'), ('wish', 'ended'), ('wish', 'flagship'), ('wish', 'requires'), ('wish', 'consider'), ('wish', 'meerkats'), ('wish', 'mention'), ('wish', 'pink'), ('wish', 'excel'), ('wish', 'method'), ('wish', 'displaying'), ('frank', 'such'), ('frank', 'about'), ('frank', 'loads'), ('frank', 'kicking'), ('frank', 'beautiful'), ('frank', 'snap'), ('frank', 'wish'), ('frank', 'totally'), ('frank', '32sii'), ('frank', 'ended'), ('frank', 'flagship'), ('frank', 'requires'), ('frank', 'consider'), ('frank', 'meerkats'), ('frank', 'mention'), ('frank', 'pink'), ('frank', 'excel'), ('frank', 'method'), ('frank', 'displaying'), ('totally', 'such'), ('totally', 'about'), ('totally', 'loads'), ('totally', 'kicking'), ('totally', 'beautiful'), ('totally', 'snap'), ('totally', 'wish'), ('totally', 'frank'), ('totally', '32sii'), ('totally', 'ended'), ('totally', 'flagship'), ('totally', 'requires'), ('totally', 'consider'), ('totally', 'meerkats'), ('totally', 'mention'), ('totally', 'pink'), ('totally', 'excel'), ('totally', 'method'), ('totally', 'displaying'), ('32sii', 'such'), ('32sii', 'about'), ('32sii', 'loads'), ('32sii', 'kicking'), ('32sii', 'beautiful'), ('32sii', 'snap'), ('32sii', 'wish'), ('32sii', 'frank'), ('32sii', 'totally'), ('32sii', 'ended'), ('32sii', 'flagship'), ('32sii', 'requires'), ('32sii', 'consider'), ...

# %%
model = models.Word2Vec(tr)

# %%
for i in tr:
  print((i[0],i[1]),model.similarity(i[0],i[1]))
# Out:
# ('such', 'about') 0.10771207
# ('such', 'loads') 0.027846642
# ('such', 'kicking') 0.066092215
# ('such', 'beautiful') -0.083372355
# ('such', 'snap') 0.10436504
# ('such', 'wish') -0.01933147
# ('such', 'frank') 0.03176985
# ('such', 'totally') -0.11698066
# ('such', '32sii') -0.24134493
# ('such', 'ended') -0.022538133
# ('such', 'flagship') -0.069670364
# ('such', 'requires') -0.07110736
# ('such', 'consider') 0.057708513
# ('such', 'meerkats') 0.16443731
# ('such', 'mention') 0.02772508
# ('such', 'pink') -0.06502894
# ('such', 'excel') -0.101000756
# ('such', 'method') -0.0058728014
# ('such', 'displaying') 0.0061349566
# ('about', 'such') 0.10771207
# ('about', 'loads') 0.11501858
# ('about', 'kicking') 0.0017287284
# ('about', 'beautiful') -0.17562687
# ('about', 'snap') -0.0047463607
# ('about', 'wish') 0.05753748
# ('about', 'frank') 0.01701467
# ('about', 'totally') -0.09442656
# ('about', '32sii') -0.021926317
# ('about', 'ended') -0.03956965
# ('about', 'flagship') 0.0073192734
# ('about', 'requires') 0.014233294
# ('about', 'consider') 0.053299632
# ('about', 'meerkats') -0.06660466
# ('about', 'mention') -0.049561102
# ('about', 'pink') 0.1099064
# ('about', 'excel') -0.04417509
# ('about', 'method') -0.008091675
# ('about', 'displaying') -0.108990885
# ('loads', 'such') 0.027846642
# ('loads', 'about') 0.11501858
# ('loads', 'kicking') -0.09000181
# ('loads', 'beautiful') -0.101369366
# ('loads', 'snap') 0.02003567
# ('loads', 'wish') 0.09797669
# ('loads', 'frank') 0.20574482
# ('loads', 'totally') 0.1085659
# ('loads', '32sii') 0.03608078
# ('loads', 'ended') -0.107962914
# ('loads', 'flagship') -0.012180882
# ('loads', 'requires') 0.0337671
# ('loads', 'consider') -0.026062483
# ('loads', 'meerkats') -0.00067224784
# ('loads', 'mention') -0.03429266
# ('loads', 'pink') 0.06332451
# ('loads', 'excel') 0.01315766
# ('loads', 'method') -0.043516636
# ('loads', 'displaying') -0.12814341
# ('kicking', 'such') 0.066092215
# ('kicking', 'about') 0.0017287284
# ('kicking', 'loads') -0.09000181
# ('kicking', 'beautiful') -0.020074237
# ('kicking', 'snap') 0.12609172
# ('kicking', 'wish') -0.071974106
# ('kicking', 'frank') 0.017981786
# ('kicking', 'totally') -0.16502936
# ('kicking', '32sii') -0.019741144
# ('kicking', 'ended') -0.13438684
# ('kicking', 'flagship') -0.084818676
# ('kicking', 'requires') -0.07737688
# ('kicking', 'consider') -0.07187182
# ('kicking', 'meerkats') 0.08702629
# ('kicking', 'mention') -0.077375874
# ('kicking', 'pink') 0.06733014
# ('kicking', 'excel') 0.025827546
# ('kicking', 'method') -0.027523847
# ('kicking', 'displaying') -0.009999114
# ('beautiful', 'such') -0.083372355
# ('beautiful', 'about') -0.17562687
# ('beautiful', 'loads') -0.101369366
# ('beautiful', 'kicking') -0.020074237
# ('beautiful', 'snap') -0.16761729
# ('beautiful', 'wish') -0.03547267
# ('beautiful', 'frank') -0.14897794
# ('beautiful', 'totally') -0.030298842
# ('beautiful', '32sii') -0.07305742
# ('beautiful', 'ended') 0.13208725
# ('beautiful', 'flagship') 0.21866812
# ('beautiful', 'requires') 0.030417643
# ('beautiful', 'consider') -0.04853362
# ('beautiful', 'meerkats') -0.027155966
# ('beautiful', 'mention') -0.03067799
# ('beautiful', 'pink') -0.15483469
# ('beautiful', 'excel') -0.046315335
# ('beautiful', 'method') 0.08180025
# ('beautiful', 'displaying') 0.11338198
# ('snap', 'such') 0.10436504
# ('snap', 'about') -0.0047463607
# ('snap', 'loads') 0.02003567
# ('snap', 'kicking') 0.12609172
# ('snap', 'beautiful') -0.16761729
# ('snap', 'wish') -0.010228583
# ('snap', 'frank') -0.03711542
# ('snap', 'totally') 0.012285315
# ('snap', '32sii') 0.040946994
# ('snap', 'ended') -0.24073465
# ('snap', 'flagship') 0.10318058
# ('snap', 'requires') 0.08726211
# ('snap', 'consider') -0.05356567
# ('snap', 'meerkats') 0.18628696
# ('snap', 'mention') 0.07238986
# ('snap', 'pink') -0.023002196
# ('snap', 'excel') -0.009590311
# ('snap', 'method') -0.040935155
# ('snap', 'displaying') -0.03658563
# ('wish', 'such') -0.01933147
# ('wish', 'about') 0.05753748
# ('wish', 'loads') 0.09797669
# ('wish', 'kicking') -0.071974106
# ('wish', 'beautiful') -0.03547267
# ('wish', 'snap') -0.010228583
# ('wish', 'frank') -0.11628685
# ('wish', 'totally') 0.07539527
# ('wish', '32sii') -0.010042373
# ('wish', 'ended') -0.13679916
# ('wish', 'flagship') 0.085670725
# ('wish', 'requires') 0.050688375
# ('wish', 'consider') -0.051617414
# ('wish', 'meerkats') 0.050566893
# ('wish', 'mention') -0.029633895
# ('wish', 'pink') 0.043272447
# ('wish', 'excel') 0.09596355
# ('wish', 'method') 0.033224434
# ('wish', 'displaying') 0.05866119
# ('frank', 'such') 0.03176985
# ('frank', 'about') 0.01701467
# ('frank', 'loads') 0.20574482
# ('frank', 'kicking') 0.017981786
# ('frank', 'beautiful') -0.14897794
# ('frank', 'snap') -0.03711542
# ('frank', 'wish') -0.11628685
# ('frank', 'totally') -0.104885034
# ('frank', '32sii') 0.04953589
# ('frank', 'ended') 0.1289787
# ('frank', 'flagship') -0.13575543
# ('frank', 'requires') 0.0024159215
# ('frank', 'consider') 0.052048445
# ('frank', 'meerkats') -0.07386412
# ('frank', 'mention') 0.05236767
# ('frank', 'pink') 0.0788041
# ('frank', 'excel') 0.10036014
# ('frank', 'method') 0.014856036
# ('frank', 'displaying') -0.14391738
# ('totally', 'such') -0.11698066
# ('totally', 'about') -0.09442656
# ('totally', 'loads') 0.1085659
# ('totally', 'kicking') -0.16502936
# ('totally', 'beautiful') -0.030298842
# ('totally', 'snap') 0.012285315
# ('totally', 'wish') 0.07539527
# ('totally', 'frank') -0.104885034
# ('totally', '32sii') -0.063123584
# ('totally', 'ended') -0.027239988
# ('totally', 'flagship') -0.03249285
# ('totally', 'requires') 0.20065112
# ('totally', 'consider') 0.10490912
# ('totally', 'meerkats') -0.0687205
# ('totally', 'mention') 0.054432012
# ('totally', 'pink') 0.15913291
# ('totally', 'excel') 0.052134417
# ('totally', 'method') -0.0067559434
# ('totally', 'displaying') 0.15327986
# ('32sii', 'such') -0.24134493
# ('32sii', 'about') -0.021926317
# ('32sii', 'loads') 0.03608078
# ('32sii', 'kicking') -0.019741144
# ('32sii', 'beautiful') -0.07305742
# ('32sii', 'snap') 0.040946994
# ('32sii', 'wish') -0.010042373
# ('32sii', 'frank') 0.04953589
# ('32sii', 'totally') -0.063123584
# ('32sii', 'ended') 0.021521486
# ('32sii', 'flagship') -0.07444462
# ('32sii', 'requires') 0.25576264
# ('32sii', 'consider') 0.089135624
# ('32sii', 'meerkats') -0.12073356
# ('32sii', 'mention') -0.098553374
# ('32sii', 'pink') 0.09749958
# ('32sii', 'excel') -0.005710867
# ('32sii', 'method') 0.095455885
# ('32sii', 'displaying') 0.06669625
# ('ended', 'such') -0.022538133
# ('ended', 'about') -0.03956965
# ('ended', 'loads') -0.107962914
# ('ended', 'kicking') -0.13438684
# ('ended', 'beautiful') 0.13208725
# ('ended', 'snap') -0.24073465
# ('ended', 'wish') -0.13679916
# ('ended', 'frank') 0.1289787
# ('ended', 'totally') -0.027239988
# ('ended', '32sii') 0.021521486
# ('ended', 'flagship') -0.07333037
# ('ended', 'requires') -0.035593864
# ('ended', 'consider') 0.0889553
# ('ended', 'meerkats') -0.12325792
# ('ended', 'mention') 0.06316175
# ('ended', 'pink') -0.1223191
# ('ended', 'excel') 0.047274724
# ('ended', 'method') 0.049827952
# ('ended', 'displaying') 0.022849487
# ('flagship', 'such') -0.069670364
# ('flagship', 'about') 0.0073192734
# ('flagship', 'loads') -0.012180882
# ('flagship', 'kicking') -0.084818676
# ('flagship', 'beautiful') 0.21866812
# ('flagship', 'snap') 0.10318058
# ('flagship', 'wish') 0.085670725
# ('flagship', 'frank') -0.13575543
# ('flagship', 'totally') -0.03249285
# ('flagship', '32sii') -0.07444462
# ('flagship', 'ended') -0.07333037
# ('flagship', 'requires') 0.04654217
# ('flagship', 'consider') -0.10605823
# ('flagship', 'meerkats') -0.08967055
# ('flagship', 'mention') -0.025491292
# ('flagship', 'pink') -0.0134899765
# ('flagship', 'excel') 0.014694521
# ('flagship', 'method') 0.015984565
# ('flagship', 'displaying') 0.0024892758
# ('requires', 'such') -0.07110736
# ('requires', 'about') 0.014233294
# ('requires', 'loads') 0.0337671
# ('requires', 'kicking') -0.07737688
# ('requires', 'beautiful') 0.030417643
# ('requires', 'snap') 0.08726211
# ('requires', 'wish') 0.050688375
# ('requires', 'frank') 0.0024159215
# ('requires', 'totally') 0.20065112
# ('requires', '32sii') 0.25576264
# ('requires', 'ended') -0.035593864
# ('requires', 'flagship') 0.04654217
# ('requires', 'consider') -0.004336934
# ('requires', 'meerkats') -0.06634411
# ('requires', 'mention') -0.028990146
# ('requires', 'pink') -0.005777492
# ('requires', 'excel') 0.00034115463
# ('requires', 'method') 0.106436506
# ('requires', 'displaying') 0.051287405
# ('consider', 'such') 0.057708513
# ('consider', 'about') 0.053299632
# ('consider', 'loads') -0.026062483
# ('consider', 'kicking') -0.07187182
# ('consider', 'beautiful') -0.04853362
# ('consider', 'snap') -0.05356567
# ('consider', 'wish') -0.051617414
# ('consider', 'frank') 0.052048445
# ('consider', 'totally') 0.10490912
# ('consider', '32sii') 0.089135624
# ('consider', 'ended') 0.0889553
# ('consider', 'flagship') -0.10605823
# ('consider', 'requires') -0.004336934
# ('consider', 'meerkats') -0.07166819
# ('consider', 'mention') 0.0018659547
# ('consider', 'pink') 0.09508024
# ('consider', 'excel') -0.12203007
# ('consider', 'method') 0.003118406
# ('consider', 'displaying') -0.03286418
# ('meerkats', 'such') 0.16443731
# ('meerkats', 'about') -0.06660466
# ('meerkats', 'loads') -0.00067224784
# ('meerkats', 'kicking') 0.08702629
# ('meerkats', 'beautiful') -0.027155966
# ('meerkats', 'snap') 0.18628696
# ('meerkats', 'wish') 0.050566893
# ('meerkats', 'frank') -0.07386412
# ('meerkats', 'totally') -0.0687205
# ('meerkats', '32sii') -0.12073356
# ('meerkats', 'ended') -0.12325792
# ('meerkats', 'flagship') -0.08967055
# ('meerkats', 'requires') -0.06634411
# ('meerkats', 'consider') -0.07166819
# ('meerkats', 'mention') -0.041503903
# ('meerkats', 'pink') 0.10388418
# ('meerkats', 'excel') 0.07017868
# ('meerkats', 'method') -0.08498416
# ('meerkats', 'displaying') -0.036082026
# ('mention', 'such') 0.02772508
# ('mention', 'about') -0.049561102
# ('mention', 'loads') -0.03429266
# ('mention', 'kicking') -0.077375874
# ('mention', 'beautiful') -0.03067799
# ('mention', 'snap') 0.07238986
# ('mention', 'wish') -0.029633895
# ('mention', 'frank') 0.05236767
# ('mention', 'totally') 0.054432012
# ('mention', '32sii') -0.098553374
# ('mention', 'ended') 0.06316175
# ('mention', 'flagship') -0.025491292
# ('mention', 'requires') -0.028990146
# ('mention', 'consider') 0.0018659547
# ('mention', 'meerkats') -0.041503903
# ('mention', 'pink') 0.05599162
# ('mention', 'excel') 0.15720297
# ('mention', 'method') 0.052034233
# ('mention', 'displaying') 0.09087245
# ('pink', 'such') -0.06502894
# ('pink', 'about') 0.1099064
# ('pink', 'loads') 0.06332451
# ('pink', 'kicking') 0.06733014
# ('pink', 'beautiful') -0.15483469
# ('pink', 'snap') -0.023002196
# ('pink', 'wish') 0.043272447
# ('pink', 'frank') 0.0788041
# ('pink', 'totally') 0.15913291
# ('pink', '32sii') 0.09749958
# ('pink', 'ended') -0.1223191
# ('pink', 'flagship') -0.0134899765
# ('pink', 'requires') -0.005777492
# ('pink', 'consider') 0.09508024
# ('pink', 'meerkats') 0.10388418
# ('pink', 'mention') 0.05599162
# ('pink', 'excel') 0.07465691
# ('pink', 'method') 0.17017458
# ('pink', 'displaying') -0.09882454
# ('excel', 'such') -0.101000756
# ('excel', 'about') -0.04417509
# ('excel', 'loads') 0.01315766
# ('excel', 'kicking') 0.025827546
# ('excel', 'beautiful') -0.046315335
# ('excel', 'snap') -0.009590311
# ('excel', 'wish') 0.09596355
# ('excel', 'frank') 0.10036014
# ('excel', 'totally') 0.052134417
# ('excel', '32sii') -0.005710867
# ('excel', 'ended') 0.047274724
# ('excel', 'flagship') 0.014694521
# ('excel', 'requires') 0.00034115463
# ('excel', 'consider') -0.12203007
# ('excel', 'meerkats') 0.07017868
# ('excel', 'mention') 0.15720297
# ('excel', 'pink') 0.07465691
# ('excel', 'method') 0.06316832
# ('excel', 'displaying') 0.16454692
# ('method', 'such') -0.0058728014
# ('method', 'about') -0.008091675
# ('method', 'loads') -0.043516636
# ('method', 'kicking') -0.027523847
# ('method', 'beautiful') 0.08180025
# ('method', 'snap') -0.040935155
# ('method', 'wish') 0.033224434
# ('method', 'frank') 0.014856036
# ('method', 'totally') -0.0067559434
# ('method', '32sii') 0.095455885
# ('method', 'ended') 0.049827952
# ('method', 'flagship') 0.015984565
# ('method', 'requires') 0.106436506
# ('method', 'consider') 0.003118406
# ('method', 'meerkats') -0.08498416
# ('method', 'mention') 0.052034233
# ('method', 'pink') 0.17017458
# ('method', 'excel') 0.06316832
# ('method', 'displaying') 0.043871175
# ('displaying', 'such') 0.0061349566
# ('displaying', 'about') -0.108990885
# ('displaying', 'loads') -0.12814341
# ('displaying', 'kicking') -0.009999114
# ('displaying', 'beautiful') 0.11338198
# ('displaying', 'snap') -0.03658563
# ('displaying', 'wish') 0.05866119
# ('displaying', 'frank') -0.14391738
# ('displaying', 'totally') 0.15327986
# ('displaying', '32sii') 0.06669625
# ('displaying', 'ended') 0.022849487
# ('displaying', 'flagship') 0.0024892758
# ('displaying', 'requires') 0.051287405
# ('displaying', 'consider') -0.03286418
# ('displaying', 'meerkats') -0.036082026
# ('displaying', 'mention') 0.09087245
# ('displaying', 'pink') -0.09882454
# ('displaying', 'excel') 0.16454692
# ('displaying', 'method') 0.043871175
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
